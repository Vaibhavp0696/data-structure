# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
itanic = sns.load_dataset("titanic")
sns.catplot(data='titanic', x="sex", y="survived", hue="class", kind="bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 itanic = sns.load_dataset("titanic")
# ----> 2 sns.catplot(data='titanic', x="sex", y="survived", hue="class", kind="bar")
#
# File c:\Users\VAIBHAV\miniconda3\Lib\site-packages\seaborn\categorical.py:2782, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2779     elif x is not None and y is not None:
#    2780         raise ValueError("Cannot pass values for both `x` and `y`.")
# -> 2782 p = Plotter(
#    2783     data=data,
#    2784     variables=dict(
#    2785         x=x, y=y, hue=hue, row=row, col=col, units=units, weight=weights
# ...

# %% [markdown]
# survival anf non-survival count by gender

# %%
sns.countplot(df, x='alive', hue = 'sex')
plt.title("Survival and non-survival count by")
plt.show()

# %%
sns.countplot(df, y = 'class', palette="coolwarm")
plt.title('Number of passenger by class')
plt.show()
# Out:
# C:\Users\VAIBHAV\AppData\Local\Temp\ipykernel_7600\4040978172.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, y = 'class', palette="coolwarm")

# %%
sns.barplot(df ,x='class', y="survived",palette='coolwarm')
plt.title('survival Rate by class')
plt.show()
# Out:
# C:\Users\VAIBHAV\AppData\Local\Temp\ipykernel_12880\2466517737.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(df ,x='class', y="survived",palette='coolwarm')

# %%
sns.histplot(df, x='age', bins=30,kde=True , color = 'red')
plt.title("Age Distribution")
plt.show()

# %%
sns.violinplot(df, x='class', y='age', hue='sex', palette='coolwarm')
plt.title('age distribution by class')
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("country_wise_latest.csv")
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
top_10 = df.nlargest(10, 'Confirmed')
sns.barplot(x="Confirmed", y="Country/Region", data=top_10, palette="viridis")
plt.title("Top 10 Countries with highest number of congitmed")
plt.show()
# Out:
# C:\Users\VAIBHAV\AppData\Local\Temp\ipykernel_7600\4118681813.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Confirmed", y="Country/Region", data=top_10, palette="viridis")

# %%
top_countries = df.nlargest(10, 'Deaths / 100 Cases')
plt.figure(figsize=(12,6))
sns.barplot(x='Deaths / 100 Cases', y='Country/Region', data=top_countries, palette='Reds')
plt.title('Top 10 Countries by Death Rate')
plt.show()
# Out:
# C:\Users\VAIBHAV\AppData\Local\Temp\ipykernel_7600\2607634325.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Deaths / 100 Cases', y='Country/Region', data=top_countries, palette='Reds')

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='Confirmed last week', y='1 week change', data=df, marker='o')
plt.title('Weekly Case Growth')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Confirmed', y='Active', data=df, hue='WHO Region', palette='viridis')
plt.title('Active Case vs Confirmed case')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Deaths / 100 Cases'], bins = 30, kde=True, color='red')
plt.title("Distribution of Death rate")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='WHO Region', y='New cases', data=df, palette='pastel')
plt.xticks(rotation=45)
plt.title('New Cases by WHO Region')
plt.show()

# %%
plt.figure(figsize=(8,8))
df.groupby('WHO Region')['Confirmed'].sum().plot.pie(autopct='%1.1f%%', cmap='coolwarm', startangle=140)
plt.ylabel('')
plt.title('Confirmed Cases Distribution by WHO Region')
plt.show()

# %%
sns.pairplot(df[['Confirmed', 'Deaths', 'Recovered', 'Active']], diag_kind='kde', plot_kws={'alpha':0.5})
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.relplot(data=df, x="Deaths", y="Active",hue="WHO Region",height=6)
plt.title("CASES")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.figure(figsize=(12,6))
#       2 sns.relplot(data=df, x="Deaths", y="Active",hue="WHO Region",height=6)
#       3 plt.title("CASES")
#
# NameError: name 'plt' is not defined
